# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision.transforms as transforms
import medmnist
from medmnist import INFO, Evaluator
import matplotlib.pyplot as plt
import numpy as np
from torch.utils.data import DataLoader

# Configurando o dispositivo (GPU se disponível)
device = torch.device('mps' if torch.backends.mps.is_available() else 'cpu')
print(f'Usando dispositivo: {device}')
# Out:
# Usando dispositivo: cpu

# %%
# Definindo hiperparâmetros
latent_dim = 100
image_size = 28
batch_size = 32
num_epochs = 20
lr = 0.0002
beta1 = 0.5

# Carregando o dataset PathMNIST
data_flag = 'pathmnist'
download = True

info = INFO[data_flag]
task = info['task']
n_channels = info['n_channels']
n_classes = len(info['label'])

# Definindo as transformações
transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.5,), (0.5,))
])

DataClass = getattr(medmnist, info['python_class'])
display(DataClass)
# Out:
# medmnist.dataset.PathMNIST

# %%
# Preparando os dados de treino
train_dataset = DataClass(split='train', transform=transform, download=download)
train_loader = DataLoader(dataset=train_dataset, batch_size=batch_size, shuffle=True)
# Out:
# Downloading https://zenodo.org/records/10519652/files/pathmnist.npz?download=1 to C:\Users\flavi\.medmnist\pathmnist.npz
# 100%|██████████| 206M/206M [00:26<00:00, 7.86MB/s]

# %%
# Definindo o Gerador
class Generator(nn.Module):
    def __init__(self):
        super(Generator, self).__init__()
        self.main = nn.Sequential(
            # Camada de entrada
            nn.Linear(latent_dim, 256),
            nn.LeakyReLU(0.2),
            
            # Camadas intermediárias
            nn.Linear(256, 512),
            nn.LeakyReLU(0.2),
            
            nn.Linear(512, 1024),
            nn.LeakyReLU(0.2),
            
            # Camada de saída
            nn.Linear(1024, image_size * image_size * n_channels),
            nn.Tanh()
        )

    def forward(self, x):
        img = self.main(x)
        img = img.view(-1, n_channels, image_size, image_size)
        return img

# %%
# Definindo o Discriminador
class Discriminator(nn.Module):
    def __init__(self):
        super(Discriminator, self).__init__()
        self.main = nn.Sequential(
            # Camada de entrada
            nn.Linear(image_size * image_size * n_channels, 1024),
            nn.LeakyReLU(0.2),
            nn.Dropout(0.3),
            
            # Camadas intermediárias
            nn.Linear(1024, 512),
            nn.LeakyReLU(0.2),
            nn.Dropout(0.3),
            
            nn.Linear(512, 256),
            nn.LeakyReLU(0.2),
            nn.Dropout(0.3),
            
            # Camada de saída
            nn.Linear(256, 1),
            nn.Sigmoid()
        )

    def forward(self, x):
        x = x.view(-1, image_size * image_size * n_channels)
        return self.main(x)

# %%
# Inicializando os modelos
generator = Generator().to(device)
discriminator = Discriminator().to(device)

# Definindo as funções de perda e otimizadores
criterion = nn.BCELoss()
g_optimizer = optim.Adam(generator.parameters(), lr=lr, betas=(beta1, 0.999))
d_optimizer = optim.Adam(discriminator.parameters(), lr=lr, betas=(beta1, 0.999))

# %%
# Função para salvar imagens geradas
def save_generated_images(epoch, generator, fixed_noise):
    with torch.no_grad():
        fake_images = generator(fixed_noise).cpu()
        plt.figure(figsize=(10, 10))
        for i in range(16):
            plt.subplot(4, 4, i+1)
            plt.imshow(fake_images[i][0], cmap='gray')
            plt.axis('off')
        plt.savefig(f'fake_images_epoch_{epoch}.png')
        plt.close()

# %%
# Gerando ruído fixo para visualização
fixed_noise = torch.randn(16, latent_dim).to(device)
display(fixed_noise)
# Out:
# tensor([[ 0.2172,  0.1918, -1.3465,  ..., -0.4307, -0.4913,  0.4790],
#         [-0.8995, -0.0560, -2.0014,  ...,  1.1169,  0.8679, -0.9819],
#         [-0.6868, -0.3542, -0.0173,  ...,  1.8782, -0.4141, -0.8214],
#         ...,
#         [ 0.1527,  1.2872,  0.4429,  ...,  1.4363, -1.0335,  1.5079],
#         [-1.1808,  0.2156,  0.2944,  ...,  0.4965,  2.1354,  2.0545],
#         [ 0.1411, -0.1211, -0.4483,  ..., -0.4908,  0.3568, -0.0707]])

# %%
for epoch in range(num_epochs):
    for i, (real_images, _) in enumerate(train_loader):
        batch_size = real_images.size(0)
        real_images = real_images.to(device)
        
        # Labels para dados reais e falsos
        real_labels = torch.ones(batch_size, 1).to(device)
        fake_labels = torch.zeros(batch_size, 1).to(device)
        
        # Treinar o Discriminador
        discriminator.zero_grad()
        outputs = discriminator(real_images)
        d_loss_real = criterion(outputs, real_labels)
        
        noise = torch.randn(batch_size, latent_dim).to(device)
        fake_images = generator(noise)
        outputs = discriminator(fake_images.detach())
        d_loss_fake = criterion(outputs, fake_labels)
        
        d_loss = d_loss_real + d_loss_fake
        d_loss.backward()
        d_optimizer.step()
        
        # Treinar o Gerador
        generator.zero_grad()
        outputs = discriminator(fake_images)
        g_loss = criterion(outputs, real_labels)
        g_loss.backward()
        g_optimizer.step()
        
        if (i + 1) % 100 == 0:
            print(f'Epoch [{epoch}/{num_epochs}], Step [{i+1}/{len(train_loader)}], '
                  f'd_loss: {d_loss.item():.4f}, g_loss: {g_loss.item():.4f}')
    
    # Salvar imagens a cada 05 épocas
    if (epoch + 1) % 5 == 0:
        save_generated_images(epoch + 1, generator, fixed_noise)
# Out:
# Epoch [0/20], Step [100/2813], d_loss: 0.7166, g_loss: 0.7965
# Epoch [0/20], Step [200/2813], d_loss: 1.2152, g_loss: 0.9672
# Epoch [0/20], Step [300/2813], d_loss: 1.3022, g_loss: 0.7433
# Epoch [0/20], Step [400/2813], d_loss: 1.4552, g_loss: 0.7951
# Epoch [0/20], Step [500/2813], d_loss: 1.4034, g_loss: 0.6721
# Epoch [0/20], Step [600/2813], d_loss: 1.3935, g_loss: 0.7091
# Epoch [0/20], Step [700/2813], d_loss: 1.3597, g_loss: 0.6759
# Epoch [0/20], Step [800/2813], d_loss: 1.3512, g_loss: 0.7779
# Epoch [0/20], Step [900/2813], d_loss: 1.3722, g_loss: 0.7687
# Epoch [0/20], Step [1000/2813], d_loss: 1.4473, g_loss: 0.6577
# Epoch [0/20], Step [1100/2813], d_loss: 1.2974, g_loss: 0.8713
# Epoch [0/20], Step [1200/2813], d_loss: 1.4091, g_loss: 0.7148
# Epoch [0/20], Step [1300/2813], d_loss: 1.3328, g_loss: 0.6939
# Epoch [0/20], Step [1400/2813], d_loss: 1.3535, g_loss: 0.7013
# Epoch [0/20], Step [1500/2813], d_loss: 1.4459, g_loss: 0.7726
# Epoch [0/20], Step [1600/2813], d_loss: 1.2862, g_loss: 0.6912
# Epoch [0/20], Step [1700/2813], d_loss: 1.3739, g_loss: 0.8259
# Epoch [0/20], Step [1800/2813], d_loss: 1.3138, g_loss: 0.7160
# Epoch [0/20], Step [1900/2813], d_loss: 1.3935, g_loss: 0.7854
# Epoch [0/20], Step [2000/2813], d_loss: 1.4714, g_loss: 0.8428
# Epoch [0/20], Step [2100/2813], d_loss: 1.3541, g_loss: 0.7693
# Epoch [0/20], Step [2200/2813], d_loss: 1.4008, g_loss: 0.6532
# Epoch [0/20], Step [2300/2813], d_loss: 1.3264, g_loss: 0.8077
# Epoch [0/20], Step [2400/2813], d_loss: 1.2690, g_loss: 0.8309
# Epoch [0/20], Step [2500/2813], d_loss: 1.3627, g_loss: 0.7549
# Epoch [0/20], Step [2600/2813], d_loss: 1.3210, g_loss: 0.8199
# Epoch [0/20], Step [2700/2813], d_loss: 1.3529, g_loss: 0.8116
# Epoch [0/20], Step [2800/2813], d_loss: 1.3180, g_loss: 0.8072
# Epoch [1/20], Step [100/2813], d_loss: 1.3394, g_loss: 0.7154
# Epoch [1/20], Step [200/2813], d_loss: 1.4057, g_loss: 0.7234
# Epoch [1/20], Step [300/2813], d_loss: 1.4191, g_loss: 0.7659
# Epoch [1/20], Step [400/2813], d_loss: 1.3205, g_loss: 0.7968
# Epoch [1/20], Step [500/2813], d_loss: 1.3530, g_loss: 0.6917
# Epoch [1/20], Step [600/2813], d_loss: 1.4153, g_loss: 0.7918
# Epoch [1/20], Step [700/2813], d_loss: 1.3894, g_loss: 0.7230
# Epoch [1/20], Step [800/2813], d_loss: 1.3794, g_loss: 0.6971
# Epoch [1/20], Step [900/2813], d_loss: 1.3838, g_loss: 0.7228
# Epoch [1/20], Step [1000/2813], d_loss: 1.4272, g_loss: 0.7413
# Epoch [1/20], Step [1100/2813], d_loss: 1.3256, g_loss: 0.7753
# Epoch [1/20], Step [1200/2813], d_loss: 1.3523, g_loss: 0.7001
# Epoch [1/20], Step [1300/2813], d_loss: 1.5045, g_loss: 0.7044
# Epoch [1/20], Step [1400/2813], d_loss: 1.3715, g_loss: 0.7405
# Epoch [1/20], Step [1500/2813], d_loss: 1.3510, g_loss: 0.7163
# Epoch [1/20], Step [1600/2813], d_loss: 1.3386, g_loss: 0.7542
# Epoch [1/20], Step [1700/2813], d_loss: 1.3096, g_loss: 0.7563
# Epoch [1/20], Step [1800/2813], d_loss: 1.4469, g_loss: 0.6125
# Epoch [1/20], Step [1900/2813], d_loss: 1.3336, g_loss: 0.7177
# Epoch [1/20], Step [2000/2813], d_loss: 1.3374, g_loss: 0.9208
# Epoch [1/20], Step [2100/2813], d_loss: 1.3855, g_loss: 0.7028
# Epoch [1/20], Step [2200/2813], d_loss: 1.3920, g_loss: 0.6768
# Epoch [1/20], Step [2300/2813], d_loss: 1.3689, g_loss: 0.7063
# Epoch [1/20], Step [2400/2813], d_loss: 1.3636, g_loss: 0.8156
# Epoch [1/20], Step [2500/2813], d_loss: 1.3848, g_loss: 0.7413
# Epoch [1/20], Step [2600/2813], d_loss: 1.4054, g_loss: 0.7666
# Epoch [1/20], Step [2700/2813], d_loss: 1.2954, g_loss: 0.7873
# Epoch [1/20], Step [2800/2813], d_loss: 1.2965, g_loss: 0.8535
# Epoch [2/20], Step [100/2813], d_loss: 1.3680, g_loss: 0.7404
# Epoch [2/20], Step [200/2813], d_loss: 1.3703, g_loss: 0.6915
# Epoch [2/20], Step [300/2813], d_loss: 1.3751, g_loss: 0.7276
# Epoch [2/20], Step [400/2813], d_loss: 1.3797, g_loss: 0.7821
# Epoch [2/20], Step [500/2813], d_loss: 1.3863, g_loss: 0.7516
# Epoch [2/20], Step [600/2813], d_loss: 1.3715, g_loss: 0.7221
# Epoch [2/20], Step [700/2813], d_loss: 1.3691, g_loss: 0.7314
# Epoch [2/20], Step [800/2813], d_loss: 1.3746, g_loss: 0.7461
# Epoch [2/20], Step [900/2813], d_loss: 1.4179, g_loss: 0.7189
# Epoch [2/20], Step [1000/2813], d_loss: 1.3996, g_loss: 0.7175
# Epoch [2/20], Step [1100/2813], d_loss: 1.4315, g_loss: 0.6899
# Epoch [2/20], Step [1200/2813], d_loss: 1.3691, g_loss: 0.6294
# Epoch [2/20], Step [1300/2813], d_loss: 1.3175, g_loss: 0.8711
# Epoch [2/20], Step [1400/2813], d_loss: 1.3843, g_loss: 0.6640
# Epoch [2/20], Step [1500/2813], d_loss: 1.3693, g_loss: 0.7249
# Epoch [2/20], Step [1600/2813], d_loss: 1.3794, g_loss: 0.6921
# Epoch [2/20], Step [1700/2813], d_loss: 1.3500, g_loss: 0.6693
# Epoch [2/20], Step [1800/2813], d_loss: 1.3821, g_loss: 0.7528
# Epoch [2/20], Step [1900/2813], d_loss: 1.3555, g_loss: 0.8056
# Epoch [2/20], Step [2000/2813], d_loss: 1.3162, g_loss: 0.7262
# Epoch [2/20], Step [2100/2813], d_loss: 1.4073, g_loss: 0.6944
# Epoch [2/20], Step [2200/2813], d_loss: 1.4072, g_loss: 0.7648
# Epoch [2/20], Step [2300/2813], d_loss: 1.3832, g_loss: 0.7056
# Epoch [2/20], Step [2400/2813], d_loss: 1.4041, g_loss: 0.7859
# Epoch [2/20], Step [2500/2813], d_loss: 1.3661, g_loss: 0.6290
# Epoch [2/20], Step [2600/2813], d_loss: 1.2736, g_loss: 0.5988
# Epoch [2/20], Step [2700/2813], d_loss: 1.4090, g_loss: 0.7641
# Epoch [2/20], Step [2800/2813], d_loss: 1.3707, g_loss: 0.7690
# Epoch [3/20], Step [100/2813], d_loss: 1.3871, g_loss: 0.7278
# Epoch [3/20], Step [200/2813], d_loss: 1.4078, g_loss: 0.6270
# Epoch [3/20], Step [300/2813], d_loss: 1.3850, g_loss: 0.7166
# Epoch [3/20], Step [400/2813], d_loss: 1.3578, g_loss: 0.7400
# Epoch [3/20], Step [500/2813], d_loss: 1.3503, g_loss: 0.7570
# Epoch [3/20], Step [600/2813], d_loss: 1.4230, g_loss: 0.7247
# Epoch [3/20], Step [700/2813], d_loss: 1.3850, g_loss: 0.7388
# Epoch [3/20], Step [800/2813], d_loss: 1.3319, g_loss: 0.7417
# Epoch [3/20], Step [900/2813], d_loss: 1.3835, g_loss: 0.7236
# Epoch [3/20], Step [1000/2813], d_loss: 1.3381, g_loss: 0.6528
# Epoch [3/20], Step [1100/2813], d_loss: 1.3993, g_loss: 0.7311
# Epoch [3/20], Step [1200/2813], d_loss: 1.3772, g_loss: 0.6764
# Epoch [3/20], Step [1300/2813], d_loss: 1.3652, g_loss: 0.6964
# Epoch [3/20], Step [1400/2813], d_loss: 1.3540, g_loss: 0.7941
# Epoch [3/20], Step [1500/2813], d_loss: 1.4645, g_loss: 0.6829
# Epoch [3/20], Step [1600/2813], d_loss: 1.3377, g_loss: 0.6614
# Epoch [3/20], Step [1700/2813], d_loss: 1.3772, g_loss: 0.7007
# Epoch [3/20], Step [1800/2813], d_loss: 1.3711, g_loss: 0.7146
# Epoch [3/20], Step [1900/2813], d_loss: 1.3795, g_loss: 0.6359
# Epoch [3/20], Step [2000/2813], d_loss: 1.3846, g_loss: 0.6877
# Epoch [3/20], Step [2100/2813], d_loss: 1.4202, g_loss: 0.6931
# Epoch [3/20], Step [2200/2813], d_loss: 1.3849, g_loss: 0.6673
# Epoch [3/20], Step [2300/2813], d_loss: 1.3908, g_loss: 0.7156
# Epoch [3/20], Step [2400/2813], d_loss: 1.3573, g_loss: 0.6961
# Epoch [3/20], Step [2500/2813], d_loss: 1.3628, g_loss: 0.6772
# Epoch [3/20], Step [2600/2813], d_loss: 1.3530, g_loss: 0.8010
# Epoch [3/20], Step [2700/2813], d_loss: 1.4048, g_loss: 0.7361
# Epoch [3/20], Step [2800/2813], d_loss: 1.3971, g_loss: 0.7379
# Epoch [4/20], Step [100/2813], d_loss: 1.4004, g_loss: 0.7330
# Epoch [4/20], Step [200/2813], d_loss: 1.3888, g_loss: 0.7110
# Epoch [4/20], Step [300/2813], d_loss: 1.3720, g_loss: 0.6215
# Epoch [4/20], Step [400/2813], d_loss: 1.3984, g_loss: 0.7510
# Epoch [4/20], Step [500/2813], d_loss: 1.3645, g_loss: 0.7001
# Epoch [4/20], Step [600/2813], d_loss: 1.3832, g_loss: 0.6763
# Epoch [4/20], Step [700/2813], d_loss: 1.3659, g_loss: 0.6955
# Epoch [4/20], Step [800/2813], d_loss: 1.3559, g_loss: 0.7046
# Epoch [4/20], Step [900/2813], d_loss: 1.3598, g_loss: 0.8000
# Epoch [4/20], Step [1000/2813], d_loss: 1.3593, g_loss: 0.7238
# Epoch [4/20], Step [1100/2813], d_loss: 1.3844, g_loss: 0.6803
# Epoch [4/20], Step [1200/2813], d_loss: 1.3577, g_loss: 0.6657
# Epoch [4/20], Step [1300/2813], d_loss: 1.3983, g_loss: 0.6849
# Epoch [4/20], Step [1400/2813], d_loss: 1.4018, g_loss: 0.7827
# Epoch [4/20], Step [1500/2813], d_loss: 1.3713, g_loss: 0.7175
# Epoch [4/20], Step [1600/2813], d_loss: 1.3659, g_loss: 0.6854
# Epoch [4/20], Step [1700/2813], d_loss: 1.4013, g_loss: 0.6786
# Epoch [4/20], Step [1800/2813], d_loss: 1.3809, g_loss: 0.6936
# Epoch [4/20], Step [1900/2813], d_loss: 1.3742, g_loss: 0.6895
# Epoch [4/20], Step [2000/2813], d_loss: 1.3800, g_loss: 0.7262
# Epoch [4/20], Step [2100/2813], d_loss: 1.3311, g_loss: 0.8058
# Epoch [4/20], Step [2200/2813], d_loss: 1.3953, g_loss: 0.7080
# Epoch [4/20], Step [2300/2813], d_loss: 1.3775, g_loss: 0.7203
# Epoch [4/20], Step [2400/2813], d_loss: 1.3670, g_loss: 0.6692
# Epoch [4/20], Step [2500/2813], d_loss: 1.4039, g_loss: 0.6854
# Epoch [4/20], Step [2600/2813], d_loss: 1.4238, g_loss: 0.6877
# Epoch [4/20], Step [2700/2813], d_loss: 1.4067, g_loss: 0.6956
# Epoch [4/20], Step [2800/2813], d_loss: 1.3600, g_loss: 0.7542
# Epoch [5/20], Step [100/2813], d_loss: 1.4133, g_loss: 0.7249
# Epoch [5/20], Step [200/2813], d_loss: 1.3878, g_loss: 0.7483
# Epoch [5/20], Step [300/2813], d_loss: 1.3924, g_loss: 0.7089
# Epoch [5/20], Step [400/2813], d_loss: 1.4079, g_loss: 0.7067
# Epoch [5/20], Step [500/2813], d_loss: 1.3886, g_loss: 0.7329
# Epoch [5/20], Step [600/2813], d_loss: 1.3864, g_loss: 0.7422
# Epoch [5/20], Step [700/2813], d_loss: 1.3746, g_loss: 0.7400
# Epoch [5/20], Step [800/2813], d_loss: 1.4038, g_loss: 0.6968
# Epoch [5/20], Step [900/2813], d_loss: 1.3488, g_loss: 0.9257
# Epoch [5/20], Step [1000/2813], d_loss: 1.3842, g_loss: 0.7242
# Epoch [5/20], Step [1100/2813], d_loss: 1.4235, g_loss: 0.6736
# Epoch [5/20], Step [1200/2813], d_loss: 1.3713, g_loss: 0.6925
# Epoch [5/20], Step [1300/2813], d_loss: 1.4214, g_loss: 0.7171
# Epoch [5/20], Step [1400/2813], d_loss: 1.3917, g_loss: 0.6936
# Epoch [5/20], Step [1500/2813], d_loss: 1.3916, g_loss: 0.6998
# Epoch [5/20], Step [1600/2813], d_loss: 1.3887, g_loss: 0.6784
# Epoch [5/20], Step [1700/2813], d_loss: 1.4149, g_loss: 0.7512
# Epoch [5/20], Step [1800/2813], d_loss: 1.3607, g_loss: 0.7483
# Epoch [5/20], Step [1900/2813], d_loss: 1.3847, g_loss: 0.7543
# Epoch [5/20], Step [2000/2813], d_loss: 1.3586, g_loss: 0.7277
# Epoch [5/20], Step [2100/2813], d_loss: 1.4179, g_loss: 0.7474
# Epoch [5/20], Step [2200/2813], d_loss: 1.3840, g_loss: 0.7270
# Epoch [5/20], Step [2300/2813], d_loss: 1.3706, g_loss: 0.7071
# Epoch [5/20], Step [2400/2813], d_loss: 1.3967, g_loss: 0.7628
# Epoch [5/20], Step [2500/2813], d_loss: 1.4146, g_loss: 0.7434
# Epoch [5/20], Step [2600/2813], d_loss: 1.3707, g_loss: 0.6933
# Epoch [5/20], Step [2700/2813], d_loss: 1.3678, g_loss: 0.7375
# Epoch [5/20], Step [2800/2813], d_loss: 1.3992, g_loss: 0.6522
# Epoch [6/20], Step [100/2813], d_loss: 1.3787, g_loss: 0.7084
# Epoch [6/20], Step [200/2813], d_loss: 1.3308, g_loss: 0.7139
# Epoch [6/20], Step [300/2813], d_loss: 1.3561, g_loss: 0.7422
# Epoch [6/20], Step [400/2813], d_loss: 1.3748, g_loss: 0.7793
# Epoch [6/20], Step [500/2813], d_loss: 1.3259, g_loss: 0.7303
# Epoch [6/20], Step [600/2813], d_loss: 1.3758, g_loss: 0.6517
# Epoch [6/20], Step [700/2813], d_loss: 1.3979, g_loss: 0.7147
# Epoch [6/20], Step [800/2813], d_loss: 1.4113, g_loss: 0.7394
# Epoch [6/20], Step [900/2813], d_loss: 1.3911, g_loss: 0.7656
# Epoch [6/20], Step [1000/2813], d_loss: 1.3898, g_loss: 0.6939
# Epoch [6/20], Step [1100/2813], d_loss: 1.4413, g_loss: 0.6731
# Epoch [6/20], Step [1200/2813], d_loss: 1.3910, g_loss: 0.6964
# Epoch [6/20], Step [1300/2813], d_loss: 1.3695, g_loss: 0.6644
# Epoch [6/20], Step [1400/2813], d_loss: 1.3756, g_loss: 0.6763
# Epoch [6/20], Step [1500/2813], d_loss: 1.3699, g_loss: 0.6957
# Epoch [6/20], Step [1600/2813], d_loss: 1.4041, g_loss: 0.6364
# Epoch [6/20], Step [1700/2813], d_loss: 1.3841, g_loss: 0.8692
# Epoch [6/20], Step [1800/2813], d_loss: 1.3672, g_loss: 0.7837
# Epoch [6/20], Step [1900/2813], d_loss: 1.3787, g_loss: 0.7365
# Epoch [6/20], Step [2000/2813], d_loss: 1.3658, g_loss: 0.6507
# Epoch [6/20], Step [2100/2813], d_loss: 1.3876, g_loss: 0.6396
# Epoch [6/20], Step [2200/2813], d_loss: 1.4203, g_loss: 0.8015
# Epoch [6/20], Step [2300/2813], d_loss: 1.3657, g_loss: 0.7326
# Epoch [6/20], Step [2400/2813], d_loss: 1.3672, g_loss: 0.7424
# Epoch [6/20], Step [2500/2813], d_loss: 1.3851, g_loss: 0.7059
# Epoch [6/20], Step [2600/2813], d_loss: 1.4344, g_loss: 0.7257
# Epoch [6/20], Step [2700/2813], d_loss: 1.3698, g_loss: 0.6745
# Epoch [6/20], Step [2800/2813], d_loss: 1.3814, g_loss: 0.6845
# Epoch [7/20], Step [100/2813], d_loss: 1.3650, g_loss: 0.7035
# Epoch [7/20], Step [200/2813], d_loss: 1.3987, g_loss: 0.7139
# Epoch [7/20], Step [300/2813], d_loss: 1.4038, g_loss: 0.7219
# Epoch [7/20], Step [400/2813], d_loss: 1.3861, g_loss: 0.7183
# Epoch [7/20], Step [500/2813], d_loss: 1.4031, g_loss: 0.7020
# Epoch [7/20], Step [600/2813], d_loss: 1.3838, g_loss: 0.7660
# Epoch [7/20], Step [700/2813], d_loss: 1.3809, g_loss: 0.7500
# Epoch [7/20], Step [800/2813], d_loss: 1.3711, g_loss: 0.7266
# Epoch [7/20], Step [900/2813], d_loss: 1.4155, g_loss: 0.6935
# Epoch [7/20], Step [1000/2813], d_loss: 1.4281, g_loss: 0.7090
# Epoch [7/20], Step [1100/2813], d_loss: 1.3822, g_loss: 0.6864
# Epoch [7/20], Step [1200/2813], d_loss: 1.3886, g_loss: 0.7262
# Epoch [7/20], Step [1300/2813], d_loss: 1.3805, g_loss: 0.6908
# Epoch [7/20], Step [1400/2813], d_loss: 1.3878, g_loss: 0.7072
# Epoch [7/20], Step [1500/2813], d_loss: 1.3918, g_loss: 0.7346
# Epoch [7/20], Step [1600/2813], d_loss: 1.3937, g_loss: 0.7366
# Epoch [7/20], Step [1700/2813], d_loss: 1.3697, g_loss: 0.6762
# Epoch [7/20], Step [1800/2813], d_loss: 1.3963, g_loss: 0.6954
# Epoch [7/20], Step [1900/2813], d_loss: 1.3382, g_loss: 0.7682
# Epoch [7/20], Step [2000/2813], d_loss: 1.3825, g_loss: 0.7050
# Epoch [7/20], Step [2100/2813], d_loss: 1.3289, g_loss: 0.7707
# Epoch [7/20], Step [2200/2813], d_loss: 1.3919, g_loss: 0.7754
# Epoch [7/20], Step [2300/2813], d_loss: 1.3760, g_loss: 0.6538
# Epoch [7/20], Step [2400/2813], d_loss: 1.3711, g_loss: 0.6609
# Epoch [7/20], Step [2500/2813], d_loss: 1.3420, g_loss: 0.7965
# Epoch [7/20], Step [2600/2813], d_loss: 1.3341, g_loss: 0.7480
# Epoch [7/20], Step [2700/2813], d_loss: 1.3868, g_loss: 0.6658
# Epoch [7/20], Step [2800/2813], d_loss: 1.3909, g_loss: 0.7166
# Epoch [8/20], Step [100/2813], d_loss: 1.3700, g_loss: 0.6762
# Epoch [8/20], Step [200/2813], d_loss: 1.3550, g_loss: 0.7359
# Epoch [8/20], Step [300/2813], d_loss: 1.3535, g_loss: 0.7158
# Epoch [8/20], Step [400/2813], d_loss: 1.3487, g_loss: 0.6732
# Epoch [8/20], Step [500/2813], d_loss: 1.4063, g_loss: 0.7783
# Epoch [8/20], Step [600/2813], d_loss: 1.4002, g_loss: 0.7028
# Epoch [8/20], Step [700/2813], d_loss: 1.4114, g_loss: 0.6563
# Epoch [8/20], Step [800/2813], d_loss: 1.3500, g_loss: 0.7078
# Epoch [8/20], Step [900/2813], d_loss: 1.3459, g_loss: 0.7147
# Epoch [8/20], Step [1000/2813], d_loss: 1.3644, g_loss: 0.7425
# Epoch [8/20], Step [1100/2813], d_loss: 1.3619, g_loss: 0.7354
# Epoch [8/20], Step [1200/2813], d_loss: 1.3526, g_loss: 0.7450
# Epoch [8/20], Step [1300/2813], d_loss: 1.3808, g_loss: 0.7113
# Epoch [8/20], Step [1400/2813], d_loss: 1.3871, g_loss: 0.6491
# Epoch [8/20], Step [1500/2813], d_loss: 1.4019, g_loss: 0.7719
# Epoch [8/20], Step [1600/2813], d_loss: 1.3353, g_loss: 0.6859
# Epoch [8/20], Step [1700/2813], d_loss: 1.3687, g_loss: 0.7229
# Epoch [8/20], Step [1800/2813], d_loss: 1.3627, g_loss: 0.7215
# Epoch [8/20], Step [1900/2813], d_loss: 1.4036, g_loss: 0.7211
# Epoch [8/20], Step [2000/2813], d_loss: 1.3793, g_loss: 0.6285
# Epoch [8/20], Step [2100/2813], d_loss: 1.3969, g_loss: 0.6900
# Epoch [8/20], Step [2200/2813], d_loss: 1.3726, g_loss: 0.6961
# Epoch [8/20], Step [2300/2813], d_loss: 1.3885, g_loss: 0.7454
# Epoch [8/20], Step [2400/2813], d_loss: 1.4085, g_loss: 0.7784
# Epoch [8/20], Step [2500/2813], d_loss: 1.4013, g_loss: 0.8164
# Epoch [8/20], Step [2600/2813], d_loss: 1.4177, g_loss: 0.6879
# Epoch [8/20], Step [2700/2813], d_loss: 1.3983, g_loss: 0.6961
# Epoch [8/20], Step [2800/2813], d_loss: 1.3739, g_loss: 0.6934
# Epoch [9/20], Step [100/2813], d_loss: 1.4001, g_loss: 0.6525
# Epoch [9/20], Step [200/2813], d_loss: 1.3557, g_loss: 0.7007
# Epoch [9/20], Step [300/2813], d_loss: 1.3683, g_loss: 0.7166
# Epoch [9/20], Step [400/2813], d_loss: 1.4429, g_loss: 0.6711
# Epoch [9/20], Step [500/2813], d_loss: 1.3741, g_loss: 0.6658
# Epoch [9/20], Step [600/2813], d_loss: 1.3734, g_loss: 0.8248
# Epoch [9/20], Step [700/2813], d_loss: 1.3470, g_loss: 0.7855
# Epoch [9/20], Step [800/2813], d_loss: 1.4014, g_loss: 0.7304
# Epoch [9/20], Step [900/2813], d_loss: 1.4272, g_loss: 0.7084
# Epoch [9/20], Step [1000/2813], d_loss: 1.3803, g_loss: 0.7282
# Epoch [9/20], Step [1100/2813], d_loss: 1.4223, g_loss: 0.6482
# Epoch [9/20], Step [1200/2813], d_loss: 1.4614, g_loss: 0.7949
# Epoch [9/20], Step [1300/2813], d_loss: 1.3421, g_loss: 0.6978
# Epoch [9/20], Step [1400/2813], d_loss: 1.3415, g_loss: 0.7788
# Epoch [9/20], Step [1500/2813], d_loss: 1.3497, g_loss: 0.6877
# Epoch [9/20], Step [1600/2813], d_loss: 1.3655, g_loss: 0.7329
# Epoch [9/20], Step [1700/2813], d_loss: 1.3985, g_loss: 0.7057
# Epoch [9/20], Step [1800/2813], d_loss: 1.3818, g_loss: 0.6710
# Epoch [9/20], Step [1900/2813], d_loss: 1.3972, g_loss: 0.6984
# Epoch [9/20], Step [2000/2813], d_loss: 1.3578, g_loss: 0.6879
# Epoch [9/20], Step [2100/2813], d_loss: 1.3675, g_loss: 0.7570
# Epoch [9/20], Step [2200/2813], d_loss: 1.3557, g_loss: 0.7636
# Epoch [9/20], Step [2300/2813], d_loss: 1.3836, g_loss: 0.7145
# Epoch [9/20], Step [2400/2813], d_loss: 1.3750, g_loss: 0.7072
# Epoch [9/20], Step [2500/2813], d_loss: 1.3890, g_loss: 0.7474
# Epoch [9/20], Step [2600/2813], d_loss: 1.3950, g_loss: 0.7011
# Epoch [9/20], Step [2700/2813], d_loss: 1.3656, g_loss: 0.7228
# Epoch [9/20], Step [2800/2813], d_loss: 1.3955, g_loss: 0.6819
# Epoch [10/20], Step [100/2813], d_loss: 1.4185, g_loss: 0.7701
# Epoch [10/20], Step [200/2813], d_loss: 1.3845, g_loss: 0.6991
# Epoch [10/20], Step [300/2813], d_loss: 1.3637, g_loss: 0.7615
# Epoch [10/20], Step [400/2813], d_loss: 1.3474, g_loss: 0.7551
# Epoch [10/20], Step [500/2813], d_loss: 1.3543, g_loss: 0.7249
# Epoch [10/20], Step [600/2813], d_loss: 1.3590, g_loss: 0.6850
# Epoch [10/20], Step [700/2813], d_loss: 1.3809, g_loss: 0.6969
# Epoch [10/20], Step [800/2813], d_loss: 1.3816, g_loss: 0.7842
# Epoch [10/20], Step [900/2813], d_loss: 1.3979, g_loss: 0.7553
# Epoch [10/20], Step [1000/2813], d_loss: 1.3686, g_loss: 0.6832
# Epoch [10/20], Step [1100/2813], d_loss: 1.3500, g_loss: 0.7272
# Epoch [10/20], Step [1200/2813], d_loss: 1.3589, g_loss: 0.7393
# Epoch [10/20], Step [1300/2813], d_loss: 1.3775, g_loss: 0.7401
# Epoch [10/20], Step [1400/2813], d_loss: 1.3532, g_loss: 0.6850
# Epoch [10/20], Step [1500/2813], d_loss: 1.4109, g_loss: 0.8221
# Epoch [10/20], Step [1600/2813], d_loss: 1.3409, g_loss: 0.6880
# Epoch [10/20], Step [1700/2813], d_loss: 1.3486, g_loss: 0.7276
# Epoch [10/20], Step [1800/2813], d_loss: 1.3829, g_loss: 0.7055
# Epoch [10/20], Step [1900/2813], d_loss: 1.3953, g_loss: 0.7144
# Epoch [10/20], Step [2000/2813], d_loss: 1.3907, g_loss: 0.7149
# Epoch [10/20], Step [2100/2813], d_loss: 1.4140, g_loss: 0.7437
# Epoch [10/20], Step [2200/2813], d_loss: 1.3543, g_loss: 0.7724
# Epoch [10/20], Step [2300/2813], d_loss: 1.3527, g_loss: 0.7220
# Epoch [10/20], Step [2400/2813], d_loss: 1.3659, g_loss: 0.7355
# Epoch [10/20], Step [2500/2813], d_loss: 1.4057, g_loss: 0.7360
# Epoch [10/20], Step [2600/2813], d_loss: 1.3715, g_loss: 0.7246
# Epoch [10/20], Step [2700/2813], d_loss: 1.4082, g_loss: 0.6875
# Epoch [10/20], Step [2800/2813], d_loss: 1.3712, g_loss: 0.6663
# Epoch [11/20], Step [100/2813], d_loss: 1.3696, g_loss: 0.7673
# Epoch [11/20], Step [200/2813], d_loss: 1.3860, g_loss: 0.7337
# Epoch [11/20], Step [300/2813], d_loss: 1.4192, g_loss: 0.7473
# Epoch [11/20], Step [400/2813], d_loss: 1.3488, g_loss: 0.7985
# Epoch [11/20], Step [500/2813], d_loss: 1.3242, g_loss: 0.7334
# Epoch [11/20], Step [600/2813], d_loss: 1.3925, g_loss: 0.7594
# Epoch [11/20], Step [700/2813], d_loss: 1.3949, g_loss: 0.7182
# Epoch [11/20], Step [800/2813], d_loss: 1.2728, g_loss: 0.7429
# Epoch [11/20], Step [900/2813], d_loss: 1.4319, g_loss: 0.7310
# Epoch [11/20], Step [1000/2813], d_loss: 1.3575, g_loss: 0.6779
# Epoch [11/20], Step [1100/2813], d_loss: 1.3852, g_loss: 0.7134
# Epoch [11/20], Step [1200/2813], d_loss: 1.3846, g_loss: 0.7005
# Epoch [11/20], Step [1300/2813], d_loss: 1.3552, g_loss: 0.6713
# Epoch [11/20], Step [1400/2813], d_loss: 1.3381, g_loss: 0.6935
# Epoch [11/20], Step [1500/2813], d_loss: 1.3763, g_loss: 0.7464
# Epoch [11/20], Step [1600/2813], d_loss: 1.3524, g_loss: 0.7244
# Epoch [11/20], Step [1700/2813], d_loss: 1.3717, g_loss: 0.7580
# Epoch [11/20], Step [1800/2813], d_loss: 1.3567, g_loss: 0.7451
# Epoch [11/20], Step [1900/2813], d_loss: 1.3812, g_loss: 0.7191
# Epoch [11/20], Step [2000/2813], d_loss: 1.3980, g_loss: 0.7480
# Epoch [11/20], Step [2100/2813], d_loss: 1.3680, g_loss: 0.7657
# Epoch [11/20], Step [2200/2813], d_loss: 1.3361, g_loss: 0.7077
# Epoch [11/20], Step [2300/2813], d_loss: 1.3381, g_loss: 0.7099
# Epoch [11/20], Step [2400/2813], d_loss: 1.3856, g_loss: 0.7492
# Epoch [11/20], Step [2500/2813], d_loss: 1.4089, g_loss: 0.6974
# Epoch [11/20], Step [2600/2813], d_loss: 1.4314, g_loss: 0.7188
# Epoch [11/20], Step [2700/2813], d_loss: 1.3930, g_loss: 0.6988
# Epoch [11/20], Step [2800/2813], d_loss: 1.3371, g_loss: 0.7659
# Epoch [12/20], Step [100/2813], d_loss: 1.3318, g_loss: 0.6991
# Epoch [12/20], Step [200/2813], d_loss: 1.3190, g_loss: 0.6845
# Epoch [12/20], Step [300/2813], d_loss: 1.3731, g_loss: 0.7107
# Epoch [12/20], Step [400/2813], d_loss: 1.3591, g_loss: 0.7225
# Epoch [12/20], Step [500/2813], d_loss: 1.3778, g_loss: 0.7657
# Epoch [12/20], Step [600/2813], d_loss: 1.3549, g_loss: 0.7002
# Epoch [12/20], Step [700/2813], d_loss: 1.3461, g_loss: 0.7601
# Epoch [12/20], Step [800/2813], d_loss: 1.4137, g_loss: 0.7234
# Epoch [12/20], Step [900/2813], d_loss: 1.3997, g_loss: 0.7448
# Epoch [12/20], Step [1000/2813], d_loss: 1.4800, g_loss: 0.7138
# Epoch [12/20], Step [1100/2813], d_loss: 1.2698, g_loss: 0.5914
# Epoch [12/20], Step [1200/2813], d_loss: 1.4426, g_loss: 0.7255
# Epoch [12/20], Step [1300/2813], d_loss: 1.4114, g_loss: 0.6793
# Epoch [12/20], Step [1400/2813], d_loss: 1.4351, g_loss: 0.6471
# Epoch [12/20], Step [1500/2813], d_loss: 1.5086, g_loss: 0.7007
# Epoch [12/20], Step [1600/2813], d_loss: 1.4004, g_loss: 0.8310
# Epoch [12/20], Step [1700/2813], d_loss: 1.3641, g_loss: 0.7911
# Epoch [12/20], Step [1800/2813], d_loss: 1.3471, g_loss: 0.7912
# Epoch [12/20], Step [1900/2813], d_loss: 1.4040, g_loss: 0.7343
# Epoch [12/20], Step [2000/2813], d_loss: 1.3539, g_loss: 0.6917
# Epoch [12/20], Step [2100/2813], d_loss: 1.3529, g_loss: 0.7570
# Epoch [12/20], Step [2200/2813], d_loss: 1.3148, g_loss: 0.8043
# Epoch [12/20], Step [2300/2813], d_loss: 1.3365, g_loss: 0.8313
# Epoch [12/20], Step [2400/2813], d_loss: 1.3923, g_loss: 0.6252
# Epoch [12/20], Step [2500/2813], d_loss: 1.4057, g_loss: 0.6766
# Epoch [12/20], Step [2600/2813], d_loss: 1.3677, g_loss: 0.7407
# Epoch [12/20], Step [2700/2813], d_loss: 1.3837, g_loss: 0.7563
# Epoch [12/20], Step [2800/2813], d_loss: 1.4166, g_loss: 0.9024
# Epoch [13/20], Step [100/2813], d_loss: 1.3314, g_loss: 0.7003
# Epoch [13/20], Step [200/2813], d_loss: 1.3576, g_loss: 0.7378
# Epoch [13/20], Step [300/2813], d_loss: 1.3666, g_loss: 0.7321
# Epoch [13/20], Step [400/2813], d_loss: 1.3793, g_loss: 0.7785
# Epoch [13/20], Step [500/2813], d_loss: 1.3433, g_loss: 0.7262
# Epoch [13/20], Step [600/2813], d_loss: 1.3851, g_loss: 0.6659
# Epoch [13/20], Step [700/2813], d_loss: 1.3701, g_loss: 0.7165
# Epoch [13/20], Step [800/2813], d_loss: 1.3414, g_loss: 0.8020
# Epoch [13/20], Step [900/2813], d_loss: 1.3911, g_loss: 0.7685
# Epoch [13/20], Step [1000/2813], d_loss: 1.3602, g_loss: 0.7344
# Epoch [13/20], Step [1100/2813], d_loss: 1.3387, g_loss: 0.7194
# Epoch [13/20], Step [1200/2813], d_loss: 1.3504, g_loss: 0.7464
# Epoch [13/20], Step [1300/2813], d_loss: 1.4247, g_loss: 0.6814
# Epoch [13/20], Step [1400/2813], d_loss: 1.3098, g_loss: 0.7343
# Epoch [13/20], Step [1500/2813], d_loss: 1.3651, g_loss: 0.8185
# Epoch [13/20], Step [1600/2813], d_loss: 1.3995, g_loss: 0.8330
# Epoch [13/20], Step [1700/2813], d_loss: 1.2380, g_loss: 0.7474
# Epoch [13/20], Step [1800/2813], d_loss: 1.4204, g_loss: 0.7384
# Epoch [13/20], Step [1900/2813], d_loss: 1.3339, g_loss: 0.7583
# Epoch [13/20], Step [2000/2813], d_loss: 1.3198, g_loss: 0.6945
# Epoch [13/20], Step [2100/2813], d_loss: 1.3833, g_loss: 0.7741
# Epoch [13/20], Step [2200/2813], d_loss: 1.3650, g_loss: 0.7766
# Epoch [13/20], Step [2300/2813], d_loss: 1.4652, g_loss: 0.7148
# Epoch [13/20], Step [2400/2813], d_loss: 1.3474, g_loss: 0.7635
# Epoch [13/20], Step [2500/2813], d_loss: 1.3493, g_loss: 0.7320
# Epoch [13/20], Step [2600/2813], d_loss: 1.4125, g_loss: 0.6992
# Epoch [13/20], Step [2700/2813], d_loss: 1.3343, g_loss: 0.7716
# Epoch [13/20], Step [2800/2813], d_loss: 1.3337, g_loss: 0.7445
# Epoch [14/20], Step [100/2813], d_loss: 1.3632, g_loss: 0.7419
# Epoch [14/20], Step [200/2813], d_loss: 1.4132, g_loss: 0.6698
# Epoch [14/20], Step [300/2813], d_loss: 1.4639, g_loss: 0.7169
# Epoch [14/20], Step [400/2813], d_loss: 1.3244, g_loss: 0.7365
# Epoch [14/20], Step [500/2813], d_loss: 1.3450, g_loss: 0.7737
# Epoch [14/20], Step [600/2813], d_loss: 1.3591, g_loss: 0.7826
# Epoch [14/20], Step [700/2813], d_loss: 1.4418, g_loss: 0.7790
# Epoch [14/20], Step [800/2813], d_loss: 1.4280, g_loss: 0.7452
# Epoch [14/20], Step [900/2813], d_loss: 1.3470, g_loss: 0.7162
# Epoch [14/20], Step [1000/2813], d_loss: 1.3141, g_loss: 0.7281
# Epoch [14/20], Step [1100/2813], d_loss: 1.3460, g_loss: 0.6980
# Epoch [14/20], Step [1200/2813], d_loss: 1.3982, g_loss: 0.6978
# Epoch [14/20], Step [1300/2813], d_loss: 1.3238, g_loss: 0.7164
# Epoch [14/20], Step [1400/2813], d_loss: 1.3521, g_loss: 0.7063
# Epoch [14/20], Step [1500/2813], d_loss: 1.3636, g_loss: 0.7472
# Epoch [14/20], Step [1600/2813], d_loss: 1.3202, g_loss: 0.7046
# Epoch [14/20], Step [1700/2813], d_loss: 1.3402, g_loss: 0.7608
# Epoch [14/20], Step [1800/2813], d_loss: 1.3646, g_loss: 0.7404
# Epoch [14/20], Step [1900/2813], d_loss: 1.3404, g_loss: 0.7120
# Epoch [14/20], Step [2000/2813], d_loss: 1.3356, g_loss: 0.7762
# Epoch [14/20], Step [2100/2813], d_loss: 1.3440, g_loss: 0.7418
# Epoch [14/20], Step [2200/2813], d_loss: 1.4231, g_loss: 0.7619
# Epoch [14/20], Step [2300/2813], d_loss: 1.3554, g_loss: 0.6803
# Epoch [14/20], Step [2400/2813], d_loss: 1.3676, g_loss: 0.7468
# Epoch [14/20], Step [2500/2813], d_loss: 1.3740, g_loss: 0.7463
# Epoch [14/20], Step [2600/2813], d_loss: 1.2990, g_loss: 0.8062
# Epoch [14/20], Step [2700/2813], d_loss: 1.3831, g_loss: 0.6959
# Epoch [14/20], Step [2800/2813], d_loss: 1.3689, g_loss: 0.6590
# Epoch [15/20], Step [100/2813], d_loss: 1.3061, g_loss: 0.7803
# Epoch [15/20], Step [200/2813], d_loss: 1.3909, g_loss: 0.7382
# Epoch [15/20], Step [300/2813], d_loss: 1.3236, g_loss: 0.8161
# Epoch [15/20], Step [400/2813], d_loss: 1.3726, g_loss: 0.7236
# Epoch [15/20], Step [500/2813], d_loss: 1.2908, g_loss: 0.8401
# Epoch [15/20], Step [600/2813], d_loss: 1.3557, g_loss: 0.7479
# Epoch [15/20], Step [700/2813], d_loss: 1.3090, g_loss: 0.7352
# Epoch [15/20], Step [800/2813], d_loss: 1.3621, g_loss: 0.7499
# Epoch [15/20], Step [900/2813], d_loss: 1.3456, g_loss: 0.8050
# Epoch [15/20], Step [1000/2813], d_loss: 1.3602, g_loss: 0.7832
# Epoch [15/20], Step [1100/2813], d_loss: 1.3214, g_loss: 0.7485
# Epoch [15/20], Step [1200/2813], d_loss: 1.4450, g_loss: 0.6596
# Epoch [15/20], Step [1300/2813], d_loss: 1.3852, g_loss: 0.7424
# Epoch [15/20], Step [1400/2813], d_loss: 1.3628, g_loss: 0.6653
# Epoch [15/20], Step [1500/2813], d_loss: 1.3820, g_loss: 0.7367
# Epoch [15/20], Step [1600/2813], d_loss: 1.3239, g_loss: 0.7501
# Epoch [15/20], Step [1700/2813], d_loss: 1.4507, g_loss: 0.7495
# Epoch [15/20], Step [1800/2813], d_loss: 1.3846, g_loss: 0.7683
# Epoch [15/20], Step [1900/2813], d_loss: 1.3745, g_loss: 0.7846
# Epoch [15/20], Step [2000/2813], d_loss: 1.3722, g_loss: 0.7539
# Epoch [15/20], Step [2100/2813], d_loss: 1.4402, g_loss: 0.7160
# Epoch [15/20], Step [2200/2813], d_loss: 1.2757, g_loss: 0.7850
# Epoch [15/20], Step [2300/2813], d_loss: 1.4411, g_loss: 0.7956
# Epoch [15/20], Step [2400/2813], d_loss: 1.3645, g_loss: 0.6460
# Epoch [15/20], Step [2500/2813], d_loss: 1.4229, g_loss: 0.6891
# Epoch [15/20], Step [2600/2813], d_loss: 1.3635, g_loss: 0.6970
# Epoch [15/20], Step [2700/2813], d_loss: 1.3505, g_loss: 0.6971
# Epoch [15/20], Step [2800/2813], d_loss: 1.3442, g_loss: 0.6758
# Epoch [16/20], Step [100/2813], d_loss: 1.4197, g_loss: 0.7462
# Epoch [16/20], Step [200/2813], d_loss: 1.3000, g_loss: 0.7205
# Epoch [16/20], Step [300/2813], d_loss: 1.2998, g_loss: 0.7814
# Epoch [16/20], Step [400/2813], d_loss: 1.3468, g_loss: 0.7081
# Epoch [16/20], Step [500/2813], d_loss: 1.3615, g_loss: 0.7725
# Epoch [16/20], Step [600/2813], d_loss: 1.3134, g_loss: 0.7727
# Epoch [16/20], Step [700/2813], d_loss: 1.3246, g_loss: 0.7854
# Epoch [16/20], Step [800/2813], d_loss: 1.3531, g_loss: 0.7947
# Epoch [16/20], Step [900/2813], d_loss: 1.3403, g_loss: 0.8051
# Epoch [16/20], Step [1000/2813], d_loss: 1.2962, g_loss: 0.7512
# Epoch [16/20], Step [1100/2813], d_loss: 1.4269, g_loss: 0.7048
# Epoch [16/20], Step [1200/2813], d_loss: 1.3800, g_loss: 0.7092
# Epoch [16/20], Step [1300/2813], d_loss: 1.3469, g_loss: 0.7259
# Epoch [16/20], Step [1400/2813], d_loss: 1.3867, g_loss: 0.7238
# Epoch [16/20], Step [1500/2813], d_loss: 1.3882, g_loss: 0.7568
# Epoch [16/20], Step [1600/2813], d_loss: 1.2997, g_loss: 0.7039
# Epoch [16/20], Step [1700/2813], d_loss: 1.2954, g_loss: 0.7459
# Epoch [16/20], Step [1800/2813], d_loss: 1.2661, g_loss: 0.7701
# Epoch [16/20], Step [1900/2813], d_loss: 1.3488, g_loss: 0.7361
# Epoch [16/20], Step [2000/2813], d_loss: 1.4459, g_loss: 0.7199
# Epoch [16/20], Step [2100/2813], d_loss: 1.3688, g_loss: 0.6788
# Epoch [16/20], Step [2200/2813], d_loss: 1.2984, g_loss: 0.6951
# Epoch [16/20], Step [2300/2813], d_loss: 1.2995, g_loss: 0.8200
# Epoch [16/20], Step [2400/2813], d_loss: 1.3996, g_loss: 0.6686
# Epoch [16/20], Step [2500/2813], d_loss: 1.3418, g_loss: 0.7589
# Epoch [16/20], Step [2600/2813], d_loss: 1.3781, g_loss: 0.7464
# Epoch [16/20], Step [2700/2813], d_loss: 1.3553, g_loss: 0.6549
# Epoch [16/20], Step [2800/2813], d_loss: 1.3936, g_loss: 0.7188
# Epoch [17/20], Step [100/2813], d_loss: 1.2942, g_loss: 0.7565
# Epoch [17/20], Step [200/2813], d_loss: 1.3745, g_loss: 0.8448
# Epoch [17/20], Step [300/2813], d_loss: 1.3328, g_loss: 0.6787
# Epoch [17/20], Step [400/2813], d_loss: 1.3799, g_loss: 0.7304
# Epoch [17/20], Step [500/2813], d_loss: 1.2928, g_loss: 0.7413
# Epoch [17/20], Step [600/2813], d_loss: 1.3822, g_loss: 0.7245
# Epoch [17/20], Step [700/2813], d_loss: 1.3837, g_loss: 0.8240
# Epoch [17/20], Step [800/2813], d_loss: 1.3323, g_loss: 0.6847
# Epoch [17/20], Step [900/2813], d_loss: 1.3850, g_loss: 0.8220
# Epoch [17/20], Step [1000/2813], d_loss: 1.4259, g_loss: 0.8671
# Epoch [17/20], Step [1100/2813], d_loss: 1.4531, g_loss: 0.7042
# Epoch [17/20], Step [1200/2813], d_loss: 1.3293, g_loss: 0.7405
# Epoch [17/20], Step [1300/2813], d_loss: 1.3457, g_loss: 0.7965
# Epoch [17/20], Step [1400/2813], d_loss: 1.4038, g_loss: 0.8109
# Epoch [17/20], Step [1500/2813], d_loss: 1.3542, g_loss: 0.7113
# Epoch [17/20], Step [1600/2813], d_loss: 1.3284, g_loss: 0.7410
# Epoch [17/20], Step [1700/2813], d_loss: 1.3834, g_loss: 0.7591
# Epoch [17/20], Step [1800/2813], d_loss: 1.3833, g_loss: 0.7116
# Epoch [17/20], Step [1900/2813], d_loss: 1.3219, g_loss: 0.8094
# Epoch [17/20], Step [2000/2813], d_loss: 1.3474, g_loss: 0.8121
# Epoch [17/20], Step [2100/2813], d_loss: 1.3423, g_loss: 0.7268
# Epoch [17/20], Step [2200/2813], d_loss: 1.3457, g_loss: 0.6828
# Epoch [17/20], Step [2300/2813], d_loss: 1.4129, g_loss: 0.7662
# Epoch [17/20], Step [2400/2813], d_loss: 1.3752, g_loss: 0.7039
# Epoch [17/20], Step [2500/2813], d_loss: 1.3417, g_loss: 0.7491
# Epoch [17/20], Step [2600/2813], d_loss: 1.3222, g_loss: 0.7051
# Epoch [17/20], Step [2700/2813], d_loss: 1.3917, g_loss: 0.7089
# Epoch [17/20], Step [2800/2813], d_loss: 1.4052, g_loss: 0.7453
# Epoch [18/20], Step [100/2813], d_loss: 1.3946, g_loss: 0.7349
# Epoch [18/20], Step [200/2813], d_loss: 1.3846, g_loss: 0.7521
# Epoch [18/20], Step [300/2813], d_loss: 1.4163, g_loss: 0.6690
# Epoch [18/20], Step [400/2813], d_loss: 1.3648, g_loss: 0.7236
# Epoch [18/20], Step [500/2813], d_loss: 1.4045, g_loss: 0.6992
# Epoch [18/20], Step [600/2813], d_loss: 1.3316, g_loss: 0.7308
# Epoch [18/20], Step [700/2813], d_loss: 1.3108, g_loss: 0.8029
# Epoch [18/20], Step [800/2813], d_loss: 1.3624, g_loss: 0.7757
# Epoch [18/20], Step [900/2813], d_loss: 1.3799, g_loss: 0.7775
# Epoch [18/20], Step [1000/2813], d_loss: 1.3492, g_loss: 0.7648
# Epoch [18/20], Step [1100/2813], d_loss: 1.3643, g_loss: 0.7618
# Epoch [18/20], Step [1200/2813], d_loss: 1.3113, g_loss: 0.7568
# Epoch [18/20], Step [1300/2813], d_loss: 1.3797, g_loss: 0.7437
# Epoch [18/20], Step [1400/2813], d_loss: 1.3608, g_loss: 0.7764
# Epoch [18/20], Step [1500/2813], d_loss: 1.3086, g_loss: 0.7521
# Epoch [18/20], Step [1600/2813], d_loss: 1.3309, g_loss: 0.7891
# Epoch [18/20], Step [1700/2813], d_loss: 1.3001, g_loss: 0.7620
# Epoch [18/20], Step [1800/2813], d_loss: 1.3745, g_loss: 0.7552
# Epoch [18/20], Step [1900/2813], d_loss: 1.2883, g_loss: 0.7942
# Epoch [18/20], Step [2000/2813], d_loss: 1.3439, g_loss: 0.7884
# Epoch [18/20], Step [2100/2813], d_loss: 1.3260, g_loss: 0.7338
# Epoch [18/20], Step [2200/2813], d_loss: 1.3212, g_loss: 0.7388
# Epoch [18/20], Step [2300/2813], d_loss: 1.3360, g_loss: 0.7918
# Epoch [18/20], Step [2400/2813], d_loss: 1.5075, g_loss: 0.7417
# Epoch [18/20], Step [2500/2813], d_loss: 1.3867, g_loss: 0.7348
# Epoch [18/20], Step [2600/2813], d_loss: 1.3773, g_loss: 0.7505
# Epoch [18/20], Step [2700/2813], d_loss: 1.3323, g_loss: 0.7317
# Epoch [18/20], Step [2800/2813], d_loss: 1.3484, g_loss: 0.9538
# Epoch [19/20], Step [100/2813], d_loss: 1.3234, g_loss: 0.7490
# Epoch [19/20], Step [200/2813], d_loss: 1.3516, g_loss: 0.7778
# Epoch [19/20], Step [300/2813], d_loss: 1.3459, g_loss: 0.7671
# Epoch [19/20], Step [400/2813], d_loss: 1.3808, g_loss: 0.7371
# Epoch [19/20], Step [500/2813], d_loss: 1.3352, g_loss: 0.7520
# Epoch [19/20], Step [600/2813], d_loss: 1.3763, g_loss: 0.7140
# Epoch [19/20], Step [700/2813], d_loss: 1.4028, g_loss: 0.7336
# Epoch [19/20], Step [800/2813], d_loss: 1.3427, g_loss: 0.7288
# Epoch [19/20], Step [900/2813], d_loss: 1.3545, g_loss: 0.6873
# Epoch [19/20], Step [1000/2813], d_loss: 1.3188, g_loss: 0.7359
# Epoch [19/20], Step [1100/2813], d_loss: 1.3550, g_loss: 0.7289
# Epoch [19/20], Step [1200/2813], d_loss: 1.3727, g_loss: 0.7215
# Epoch [19/20], Step [1300/2813], d_loss: 1.3172, g_loss: 0.7221
# Epoch [19/20], Step [1400/2813], d_loss: 1.4273, g_loss: 1.0923
# Epoch [19/20], Step [1500/2813], d_loss: 1.3882, g_loss: 0.7592
# Epoch [19/20], Step [1600/2813], d_loss: 1.4212, g_loss: 0.7008
# Epoch [19/20], Step [1700/2813], d_loss: 1.3778, g_loss: 0.8064
# Epoch [19/20], Step [1800/2813], d_loss: 1.3197, g_loss: 0.7191
# Epoch [19/20], Step [1900/2813], d_loss: 1.3309, g_loss: 0.7075
# Epoch [19/20], Step [2000/2813], d_loss: 1.3163, g_loss: 0.6759
# Epoch [19/20], Step [2100/2813], d_loss: 1.3838, g_loss: 0.6893
# Epoch [19/20], Step [2200/2813], d_loss: 1.3926, g_loss: 0.7522
# Epoch [19/20], Step [2300/2813], d_loss: 1.3825, g_loss: 0.7164
# Epoch [19/20], Step [2400/2813], d_loss: 1.3668, g_loss: 0.7652
# Epoch [19/20], Step [2500/2813], d_loss: 1.3522, g_loss: 0.8000
# Epoch [19/20], Step [2600/2813], d_loss: 1.3402, g_loss: 0.7883
# Epoch [19/20], Step [2700/2813], d_loss: 1.4128, g_loss: 0.7197
# Epoch [19/20], Step [2800/2813], d_loss: 1.3095, g_loss: 0.7605

# %%
# Salvar os modelos
torch.save(generator.state_dict(), 'generator.pth')
torch.save(discriminator.state_dict(), 'discriminator.pth')

# %%
# Após treinar o modelo
noise = torch.randn(1, latent_dim).to(device)
fake_image = generator(noise)

# Preparar a imagem para visualização
fake_image = fake_image.cpu().detach()  # Move para CPU e remove do grafo computacional
fake_image = fake_image.numpy()  # Converte para numpy array
fake_image = fake_image.squeeze()  # Remove dimensões extras
fake_image = np.transpose(fake_image, (1, 2, 0))  # Muda a ordem das dimensões para (altura, largura, canais)
fake_image = (fake_image + 1) / 2.0  # Converte de [-1,1] para [0,1]

# Plotar a imagem
plt.figure(figsize=(6, 6))
plt.imshow(fake_image, cmap='gray')
plt.axis('off')
plt.title('Imagem Médica Gerada pela GAN')
plt.show()

# %%
# Gerar múltiplas imagens para aumentar dataset
num_synthetic = 1000
synthetic_images = []

for i in range(num_synthetic):
    noise = torch.randn(1, latent_dim)
    fake = generator(noise)
    synthetic_images.append(fake)

# %%
# Converter as imagens sintéticas para o formato adequado
synthetic_images = torch.cat(synthetic_images, dim=0)
synthetic_images = synthetic_images.cpu().detach().numpy()

# Salvar as imagens sintéticas
np.save('synthetic_images.npy', synthetic_images)

# Visualizar algumas imagens geradas
plt.figure(figsize=(15, 15))
for i in range(16):
    plt.subplot(4, 4, i+1)
    img = synthetic_images[i].squeeze()
    img = np.transpose(img, (1, 2, 0))
    img = (img + 1) / 2.0
    plt.imshow(img, cmap='gray')
    plt.axis('off')
plt.suptitle('Amostras de Imagens Médicas Sintéticas Geradas')
plt.show()

# %%
# Opcional: Salvar as imagens como arquivos individuais
import os
os.makedirs('synthetic_images', exist_ok=True)
for i in range(len(synthetic_images)):
    img = synthetic_images[i].squeeze()
    img = np.transpose(img, (1, 2, 0))
    img = (img + 1) / 2.0
    plt.imsave(f'synthetic_images/synthetic_{i}.png', img, cmap='gray')
