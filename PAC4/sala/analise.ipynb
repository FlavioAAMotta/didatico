# %%
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv('turma.csv')
df.head()
# Out:
#          RA  Idade  Tempo p chegar na faculdade (min)  Irmãos  Deps  \
# 0  23-14476   36.0                               30.0     1.0   4.0
# 1  23-14338   19.0                               30.0     1.0   2.0
# 2  23-14322   19.0                               50.0     3.0   2.0
# 3  23-14398   19.0                               20.0     3.0   3.0
# 4  22-12279   23.0                               10.0     2.0   1.0
#
#   Horas de Estudo/Semana         Transporte Nota Média no Último Semestre  \
# 0                     10              carro                         74.88
# 1                      3  onibus prefeitura                            81
# 2                     24             �nibus                            79
# 3                      2              Carro                            70
# 4                algumas               moto                          69.5
#
#   Horas de Sono por Noite Trabalha
# 0                       4      sim
# 1                       5      sim
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 322 entries, 0 to 321
# Data columns (total 10 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   RA                                 37 non-null     object
#  1   Idade                              36 non-null     float64
#  2   Tempo p chegar na faculdade (min)  37 non-null     float64
#  3   Irmãos                             37 non-null     float64
#  4   Deps                               37 non-null     float64
#  5   Horas de Estudo/Semana             37 non-null     object
#  6   Transporte                         37 non-null     object
#  7   Nota Média no Último Semestre      35 non-null     object
#  8   Horas de Sono por Noite            36 non-null     object
#  9   Trabalha                           37 non-null     object
# dtypes: float64(4), object(6)
# memory usage: 25.3+ KB

# %%
df["Nota Média no Último Semestre"]=df["Nota Média no Último Semestre"].str.replace(',','.')

# %%
df['Nota Média no Último Semestre'].unique()
# Out:
# array(['74.88', '81', '79', '70', '69.5', '73', '83.00', '85.85', '75',
#        '74.5', '81.7', '80.5', '77.5', '66.6', '91.85', '63.12', '90.8',
#        '92.86', '92.85', '72', '85', '68', '86.72', '89.42', '82.5', '86',
#        '79.2', '90.14', '70.0', '84.3', '88.28', '88.42', '77.6', nan],
#       dtype=object)

# %%
sns.histplot(df['Nota Média no Último Semestre'])
# Out:
# <Axes: xlabel='Nota Média no Último Semestre', ylabel='Count'>

# %%
sns.histplot(df['Deps'])
# Out:
# <Axes: xlabel='Deps', ylabel='Count'>

# %%
sns.histplot(data=df, x='Deps', hue='Trabalha')
# Out:
# <Axes: xlabel='Deps', ylabel='Count'>

# %%
sns.histplot(data=df, x='Tempo p chegar na faculdade (min)')
# Out:
# <Axes: xlabel='Tempo p chegar na faculdade (min)', ylabel='Count'>

# %%
# Convertendo nota média no ultimo semestre para float
df['Nota Média no Último Semestre'] = df['Nota Média no Último Semestre'].astype(float)

# %%
# Existe uma faixa de horas de sono que poderia ser considerada ideal com base nas notas dos alunos?
# Horas de Sono por Noite
# Boxplot para verificar

sns.boxplot(data=df, x='Horas de Sono por Noite', y='Nota Média no Último Semestre')
# Out:
# <Axes: xlabel='Horas de Sono por Noite', ylabel='Nota Média no Último Semestre'>
