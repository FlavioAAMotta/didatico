# %%
import pandas as pd
# Out:
# C:\Users\flavi\AppData\Local\Temp\ipykernel_17024\2035458946.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
df = pd.read_csv('consulta_urgencia.csv', sep=';')

# %%
df.head()
# Out:
#   data_ref  cod_prestador                   nome_prestador  \
# 0  2023_01          48008  HOSPITAL NOSSA SENHORA DA SAUDE
# 1  2023_01          48008  HOSPITAL NOSSA SENHORA DA SAUDE
# 2  2023_01          48008  HOSPITAL NOSSA SENHORA DA SAUDE
# 3  2023_01          48008  HOSPITAL NOSSA SENHORA DA SAUDE
# 4  2023_01          48008  HOSPITAL NOSSA SENHORA DA SAUDE
#
#   nome_municipio_principal_prestador uf_prestador macro_regional_prestador  \
# 0                       DOM SILVERIO           MG             LESTE DO SUL
# 1                       DOM SILVERIO           MG             LESTE DO SUL
# 2                       DOM SILVERIO           MG             LESTE DO SUL
# 3                       DOM SILVERIO           MG             LESTE DO SUL
# 4                       DOM SILVERIO           MG             LESTE DO SUL
#
#   micro_regional_prestador nome_municipio_principal_benef uf_beneficiario  \
# 0               PONTE NOVA                    ALVINOPOLIS              MG
# ...
